# %% [markdown]
# # 06 Geospatial Clustering\n\nNotebook ini menjalankan clustering geospasial DBSCAN Haversine melalui fungsi reusable dari `src.geospatial`.

# %%
from pathlib import Path\nimport sys\n\nPROJECT_ROOT = Path.cwd().resolve()\nif PROJECT_ROOT.name == 'notebooks':\n    PROJECT_ROOT = PROJECT_ROOT.parent\nif str(PROJECT_ROOT) not in sys.path:\n    sys.path.insert(0, str(PROJECT_ROOT))\n\nfrom src.geospatial import run_geospatial_clustering\nfrom src.gap_scoring import run_gap_scoring

# %%
geospatial_summary = run_geospatial_clustering()\ngeospatial_summary

# %%
gap_summary = run_gap_scoring()\ngap_summary['top_10']
