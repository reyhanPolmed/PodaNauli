# %% [markdown]
# # 05 Aspect Modeling\n\nNotebook ini menjalankan weak aspect labeling dan baseline multi-label aspect model melalui fungsi reusable dari `src.train_aspect`.

# %%
from pathlib import Path\nimport sys\n\nPROJECT_ROOT = Path.cwd().resolve()\nif PROJECT_ROOT.name == 'notebooks':\n    PROJECT_ROOT = PROJECT_ROOT.parent\nif str(PROJECT_ROOT) not in sys.path:\n    sys.path.insert(0, str(PROJECT_ROOT))\n\nfrom src.train_aspect import run_aspect_training

# %%
metrics = run_aspect_training()\nmetrics['coverage_summary']
